# %%
import os

# %%
def directory():
    directory_list = os.listdir()
    for i in directory_list:
        print(i)

# %%
file_directory = open_directory()
# Out:
# Instructions_ Personalised assignment (BE).docx
# Addendum to Genius Agreement_25.03.2025 (4) 2 2.docx
# Addendum to Genius Agreement_25.03.2025 (4) 2.docx
# esignCommunication.html
# java_script_practice
# 3. Normal Distribution.xlsx
# Screenshot 2025-10-31 at 10.29.18 AM.png
# test_folder
# mandate_cancelled.html
# Health.pdf
# math_utils.py
# Assignment Prompt.docx
# .DS_Store
# html-boilerplate
# notes.txt
# Addendum to Genius Agreement_25.03.2025 (4).docx
# .localized
# Green Team JM Listening story input and APA credit for Hurier model.pptx
# Investment-Earn-Page.png
# Screenshot 2025-10-29 at 2.52.40 PM.png
# ~$tes for FA Exam.docx
# Screenshot 2025-10-28 at 5.43.36 PM.png
# Batch 1
# Decimal – Product Requirements Document (PRD).pdf
# javascript-exercises
# agreements
# Icons.zip
# File Project.ipynb
# Screenshot 2025-10-23 at 10.35.59 AM.png
# desktop
# __pycache__
# bankAccountVerificationSuccess.html
# lamf.mov
# Cleaning-Wizards.pptx
# ET Money_stacked logo (1).png
# ...

# %%
import shutil

# %%
os.getcwd()
# Out:
# '/Users/Rakshit.Lodha/Desktop'

# %%
os.chdir("/Users/Rakshit.Lodha/Desktop")

# %%
def file_input():
    file_input = input("What's the file name? ")
    if file_input in os.listdir():
        return file_input
    else:
        print("No File Found")
        return None

# %%
file_name = file_input()
# Out:
# What's the file name?  notes.txt

# %%
def read_file(file):
    with open(file,"r") as f:
        read = f.read()
    return print(read)

# %%
read_file(file_name)
# Out:
# This is one

# %%
def write_file(file):
    # try:
    if file in os.listdir():
        write_input = input("What would you like to write?")
        with open(file, "a") as x:
            x.write(write_input)
    else:
        print("No File Found")
        return None

# %%
write_file(file_input())
# Out:
# What's the file name?  jf
# No File Found
# No File Found

# %%
read_file(file_name)
# Out:
# This is oneMy name is Khan and I'm not a terrorist

# %%
def final_function():
    while True:
        directory()
        iteration = file_input()
        read_write = input("Would you like to Read or Write file? (R/W)")
        if read_write in 'R':
            read_file(iteration)
        elif read_write in 'W':
            write_file(iteration)
        else:
            print("Invalid Choice")

        continue_choice = input("Would you like to continue to explore? (Y/N)")

        if continue_choice == 'N':
            print("Okay Goodbye!")
            break

# %%
final_function()
# Out:
# Instructions_ Personalised assignment (BE).docx
# Addendum to Genius Agreement_25.03.2025 (4) 2 2.docx
# Addendum to Genius Agreement_25.03.2025 (4) 2.docx
# esignCommunication.html
# java_script_practice
# 3. Normal Distribution.xlsx
# Screenshot 2025-10-31 at 10.29.18 AM.png
# test_folder
# mandate_cancelled.html
# Health.pdf
# math_utils.py
# Assignment Prompt.docx
# .DS_Store
# html-boilerplate
# notes.txt
# Addendum to Genius Agreement_25.03.2025 (4).docx
# .localized
# Green Team JM Listening story input and APA credit for Hurier model.pptx
# Investment-Earn-Page.png
# Screenshot 2025-10-29 at 2.52.40 PM.png
# ~$tes for FA Exam.docx
# Screenshot 2025-10-28 at 5.43.36 PM.png
# Batch 1
# Decimal – Product Requirements Document (PRD).pdf
# javascript-exercises
# agreements
# Icons.zip
# File Project.ipynb
# Screenshot 2025-10-23 at 10.35.59 AM.png
# desktop
# __pycache__
# bankAccountVerificationSuccess.html
# lamf.mov
# Cleaning-Wizards.pptx
# ET Money_stacked logo (1).png
# ...
